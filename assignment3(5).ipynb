# %%
totalamount =float(input("enter total amount:"))
target = 200000
if totalamount > 200000:
    discount = totalamount * 0.12
    total = totalamount - discount
    print("your actual amount us:",totalamount)
    print("the discount is:",discount)
    print("Final amount is:",total)
else:
    print("you are not eligible for discount")
# Out:
# enter total amount:250000
# your actual amount us: 250000.0
# the discount is: 30000.0
# Final amount is: 220000.0
